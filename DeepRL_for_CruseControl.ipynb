# %% [markdown]
# <a href="https://colab.research.google.com/github/GirolamoOddo/AppliedMath_Notebooks/blob/main/DeepRL_for_CruseControl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***DDPG Based Control for Speed Profile Tracking***
# In this notebook, the aim is to develop a controller based on DDPG Reinforcement Learning to effectively track an assigned speed for a very basic modelled racing car. To achieve this the controller will be able to act on the brake and throttle pedal.
#
# Below are some reference articles and the Keras code upon which the development is based:
#
# >  Deep Deterministic Path Following
# >  https://arxiv.org/abs/2104.06014
#
# >  Path Following with Deep Reinforcement Learning for Autonomous Cars
# >  https://www.scitepress.org/PublishedPapers/2021/107154/
#
# >  Path following for Autonomous Ground Vehicle Using DDPG Algorithm: A Reinforcement Learning Approach
# >  https://www.mdpi.com/2076-3417/13/11/6847
#
# >  Keras Implementation
# >  https://keras.io/examples/rl/ddpg_pendulum/

# %% [markdown]
# # 0 - Initialization

# %%
# @title Clear Variables

locals().clear()
globals().clear()
! pip install simple-pid
# Out:
# Requirement already satisfied: simple-pid in /usr/local/lib/python3.10/dist-packages (2.0.0)

# %%
# @title Run-Time Info
import psutil
import platform
import cpuinfo

# Informazioni sulla CPU
cpu_info = cpuinfo.get_cpu_info()
cpu_model = cpu_info['brand_raw']
cpu_architecture = platform.architecture()[0]

# Informazioni sulla RAM
ram_info = psutil.virtual_memory()
ram_total = ram_info.total

# Nome dell'ambiente di esecuzione (Google Colab)
runtime_info = "Google Colab"

print("CPU Model:", cpu_model)
print("CPU Architecture:", cpu_architecture)
print("Total RAM:", round((ram_total / (1024 ** 3)), 2), "GB")
print("Runtime info:", runtime_info)
# Out:
# CPU Model: Intel(R) Xeon(R) CPU @ 2.20GHz
# CPU Architecture: 64bit
# Total RAM: 12.67 GB
# Runtime info: Google Colab

# %% [markdown]
# # 3 - Define Sim. Environment

# %%
import random as random
import numpy as np
from matplotlib import pyplot as plt

class SimEnv:
    def __init__(self, target_speed=20.0):
        self.action_list = [0.0]
        self.current_time = 0.0
        self.target_speed = target_speed #m/s
        self.longitudinalVelocity = 0.0

    def reset(self):
        # Initialize the simulation
        self.action_list = [0.0]
        self.longitudinalVelocity = 0.0
        self.current_time = 0.0
        self.random_target_drift = np.random.randint(-int(self.target_speed /2) , int(self.target_speed /2))

    def step(self, ThrottleBrake_action):
        # Calculate the net action based on throttle and brake
        action = float(ThrottleBrake_action)
        self.action_list.append(action)

        self.current_time += 1e-1

        # Retrieve the current velocity from the FMU simulation
        G_acceleration = np.clip((- 0.5 * action**2 + 1.5 * action), a_min=-2, a_max=1) # [-]
        acceleration   = G_acceleration * 9.807

        self.longitudinalVelocity += 1e-1 * acceleration
        self.longitudinalVelocity = np.clip(self.longitudinalVelocity, a_min=0, a_max=80.0)

        # Check if the simulation should be terminated
        done = self.current_time == 10

        self.target_speed_follow = (self.target_speed + self.random_target_drift) + np.random.uniform(-1.5, 1.5)
        # Calculate the reward based on the difference between the current speed and the target speed
        reward_step = - abs(self.longitudinalVelocity - self.target_speed_follow) + 1
        if abs(self.longitudinalVelocity - self.target_speed_follow) > 2:
           reward_step = - abs(self.longitudinalVelocity - self.target_speed_follow)
        else:
           reward_step = + 1 / (abs(self.longitudinalVelocity - self.target_speed_follow) + 0.1)

        #reward_cumul += reward

        if self.current_time > 60 and abs(self.longitudinalVelocity - self.target_speed_follow) >= 30:
            reward_step -= 1000.0
            done = True

        print('Current_time_s:     ', round(self.current_time, 3))
        print('CalledAccel_in_ms2: ', round(acceleration, 5))
        print('CurrentSpeed_in_kph:', round(self.longitudinalVelocity*3.6, 3))
        print('TargetSpeed_in_kph: ', round(self.target_speed_follow*3.6, 3))
        print('Action_%:           ', round(action*100,  3))
        print('Reward:             ', round(reward_step, 3))
        if done == True: print('======== DONE: ', done, ' ========')
        print()

        return [self.longitudinalVelocity,  self.target_speed_follow], reward_step, done

    def close(self):
        return 0
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # 4 - Model Section

# %%
import gym
import tensorflow as tf
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt

tf.random.set_seed(89)
np.random.seed(89)

# %%
env = SimEnv()

num_states = 2 #current_speed, target_speed
print("Size of State Space ->  {}".format(num_states))
num_actions = 1 # ThrottelBrake_action
print("Size of Action Space ->  {}".format(num_actions))

upper_bound =  1 #action_max
lower_bound = -1 #action_min

print("Max Value of Action ->  {}".format(upper_bound))
print("Min Value of Action ->  {}".format(lower_bound))
# Out:
# Size of State Space ->  2
# Size of Action Space ->  1
# Max Value of Action ->  1
# Min Value of Action ->  -1

# %%
class OUActionNoise:
    def __init__(self, mean, std_deviation, theta=0.15, dt=1e-2, x_initial=None):
        self.theta = theta
        self.mean = mean
        self.std_dev = std_deviation
        self.dt = dt
        self.x_initial = x_initial
        self.reset()

    def __call__(self):
        # Formula taken from https://www.wikipedia.org/wiki/Ornstein-Uhlenbeck_process.
        x = (
            self.x_prev
            + self.theta * (self.mean - self.x_prev) * self.dt
            + self.std_dev * np.sqrt(self.dt) * np.random.normal(size=self.mean.shape)
        )
        # Store x into x_prev
        # Makes next noise dependent on current one
        self.x_prev = x
        return x

    def reset(self):
        if self.x_initial is not None:
            self.x_prev = self.x_initial
        else:
            self.x_prev = np.zeros_like(self.mean)

# %%
class Buffer:
    def __init__(self, buffer_capacity=100000, batch_size=64):
        # Number of "experiences" to store at max
        self.buffer_capacity = buffer_capacity
        # Num of tuples to train on.
        self.batch_size = batch_size

        # Its tells us num of times record() was called.
        self.buffer_counter = 0

        # Instead of list of tuples as the exp.replay concept go
        # We use different np.arrays for each tuple element
        self.state_buffer = np.zeros((self.buffer_capacity, num_states))
        self.action_buffer = np.zeros((self.buffer_capacity, num_actions))
        self.reward_buffer = np.zeros((self.buffer_capacity, 1))
        self.next_state_buffer = np.zeros((self.buffer_capacity, num_states))

    # Takes (s,a,r,s') obervation tuple as input
    def record(self, obs_tuple):
        # Set index to zero if buffer_capacity is exceeded,
        # replacing old records
        index = self.buffer_counter % self.buffer_capacity

        self.state_buffer[index] = obs_tuple[0]
        self.action_buffer[index] = obs_tuple[1]
        self.reward_buffer[index] = obs_tuple[2]
        self.next_state_buffer[index] = obs_tuple[3]

        self.buffer_counter += 1

    # Eager execution is turned on by default in TensorFlow 2. Decorating with tf.function allows
    # TensorFlow to build a static graph out of the logic and computations in our function.
    # This provides a large speed up for blocks of code that contain many small TensorFlow operations such as this one.
    def update(
        self, state_batch, action_batch, reward_batch, next_state_batch,
    ):
        # Training and updating Actor & Critic networks.
        # See Pseudo Code.
        with tf.GradientTape() as tape:
            target_actions = target_actor(next_state_batch, training=True)
            y = reward_batch + gamma * target_critic(
                [next_state_batch, target_actions], training=True
            )
            critic_value = critic_model([state_batch, action_batch], training=True)
            critic_loss = tf.math.reduce_mean(tf.math.square(y - critic_value))

        critic_grad = tape.gradient(critic_loss, critic_model.trainable_variables)
        critic_optimizer.apply_gradients(
            zip(critic_grad, critic_model.trainable_variables)
        )

        with tf.GradientTape() as tape:
            actions = actor_model(state_batch, training=True)
            critic_value = critic_model([state_batch, actions], training=True)
            # Used `-value` as we want to maximize the value given
            # by the critic for our actions
            actor_loss = -tf.math.reduce_mean(critic_value)

        actor_grad = tape.gradient(actor_loss, actor_model.trainable_variables)
        actor_optimizer.apply_gradients(
            zip(actor_grad, actor_model.trainable_variables)
        )

    # We compute the loss and update parameters
    def learn(self):
        # Get sampling range
        record_range = min(self.buffer_counter, self.buffer_capacity)
        # Randomly sample indices
        batch_indices = np.random.choice(record_range, self.batch_size)

        # Convert to tensors
        state_batch = tf.convert_to_tensor(self.state_buffer[batch_indices])
        action_batch = tf.convert_to_tensor(self.action_buffer[batch_indices])
        reward_batch = tf.convert_to_tensor(self.reward_buffer[batch_indices])
        reward_batch = tf.cast(reward_batch, dtype=tf.float32)
        next_state_batch = tf.convert_to_tensor(self.next_state_buffer[batch_indices])

        self.update(state_batch, action_batch, reward_batch, next_state_batch)


# This update target parameters slowly
# Based on rate `tau`, which is much less than one.
def update_target(target_weights, weights, tau):
    for (a, b) in zip(target_weights, weights):
        a.assign(b * tau + a * (1 - tau))

# %%
def get_actor():
    # Initialize weights between -3e-3 and 3-e3
    last_init = tf.random_uniform_initializer(minval=0.01, maxval=0.9)

    inputs = layers.Input(shape=(num_states,))
    out = layers.Dense(256, activation="relu")(inputs)
    out = layers.Dense(256, activation="relu")(out)
    outputs = layers.Dense(1, activation="tanh", kernel_initializer=last_init)(out)

    # Our upper bound is 2.0 for Pendulum.
    outputs = outputs * upper_bound
    model = tf.keras.Model(inputs, outputs)
    return model


def get_critic():
    # State as input
    state_input = layers.Input(shape=(num_states))
    state_out1 = layers.Dense(16, activation="relu")(state_input)
    state_out = layers.Dense(32, activation="tanh")(state_out1)

    # Action as input
    action_input = layers.Input(shape=(num_actions))
    action_out = layers.Dense(32, activation="tanh")(action_input)

    # Both are passed through seperate layer before concatenating
    concat = layers.Concatenate()([state_out, action_out])

    out = layers.Dense(256, activation="relu")(concat)
    out = layers.Dense(256, activation="tanh")(out)
    outputs = layers.Dense(1)(out)

    # Outputs single value for give state-action
    model = tf.keras.Model([state_input, action_input], outputs)

    return model

# %%
def policy(state, noise_object):
    sampled_actions = tf.squeeze(actor_model(state))
    noise = noise_object()
    # Adding noise to action
    sampled_actions = sampled_actions.numpy() + noise

    # We make sure action is within bounds
    legal_action = np.clip(sampled_actions, lower_bound, upper_bound)

    return [np.squeeze(legal_action)]

# %%
std_dev = 0.3
ou_noise = OUActionNoise(mean=np.zeros(1), std_deviation=float(std_dev) * np.ones(1))

actor_model = get_actor()
critic_model = get_critic()

target_actor = get_actor()
target_critic = get_critic()

# Making the weights equal initially
target_actor.set_weights(actor_model.get_weights())
target_critic.set_weights(critic_model.get_weights())

# Learning rate for actor-critic models
critic_lr = 0.002
actor_lr = 0.001

critic_optimizer = tf.keras.optimizers.Adam(critic_lr)
actor_optimizer = tf.keras.optimizers.Adam(actor_lr)

# Discount factor for future rewards
gamma = 0.99
# Used to update target networks
tau = 0.005

buffer = Buffer(50000, 64)

# %%
from simple_pid import PID

target_speed_ms = 15.0
env = SimEnv(target_speed = target_speed_ms)
total_episodes = 500
normalization_scalar = 80.0
# To store reward history of each episode
ep_reward_list = []
# To store average reward history of last few episodes
avg_reward_list = []
sp = 0

# Takes about 4 min to train
for ep in range(total_episodes):

    env.reset()
    prev_state = [x / normalization_scalar for x in [0.0, target_speed_ms]]

    episodic_reward = 0.0

    while env.current_time < 120:
        sp += 1
        tf_prev_state = tf.expand_dims(tf.convert_to_tensor(prev_state), 0)

        print()
        print('Episode:            ', ep)
        print('Age:                ', sp)
        action = policy(tf_prev_state, ou_noise)


        if ep % 5 == 0:
           use_pid = True
        else:
           use_pid = False

        if use_pid:
           print('PID:                ', use_pid)
           K_P = 10.0
           K_I = 5.00
           K_D = 0.10

           np_prev_state = tf_prev_state.numpy()
           pid = PID(K_P, K_I, K_D, setpoint=np_prev_state[0, 1])
           action = np.clip((np.array([pid(np_prev_state[0, 0])])), a_min=-1, a_max=1)


        # Recieve state and reward from environment.
        state, reward, done = env.step(action[0])

        buffer.record((prev_state, action, reward, state))
        episodic_reward += reward

        buffer.learn()
        update_target(target_actor.variables, actor_model.variables, tau)
        update_target(target_critic.variables, critic_model.variables, tau)

        # End this episode when `done` is True
        if done:
            break

        prev_state = [x / normalization_scalar for x in state]


    ep_reward_list.append(episodic_reward)

    # Mean of last 40 episodes
    avg_reward = np.mean(ep_reward_list[-40:])
    print()
    print("Episode: {}, Avg Reward is ==> {}".format(ep, avg_reward))
    print()
    avg_reward_list.append(avg_reward)

# Plotting graph
# Episodes versus Avg. Rewards
plt.plot(avg_reward_list)
plt.xlabel("Episode")
plt.ylabel("Avg. Epsiodic Reward")
plt.show()
# Out:
# Output streaming troncato alle ultime 5000 righe.
# Reward:              -11.436
#
#
# Episode:             17
# Age:                 18945
# Current_time_s:      33.1
# CalledAccel_in_ms2:  -12.75268
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  35.4
# Action_%:            -70.244
# Reward:              -9.833
#
#
# Episode:             17
# Age:                 18946
# Current_time_s:      33.2
# CalledAccel_in_ms2:  -12.69942
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  35.199
# Action_%:            -69.997
# Reward:              -9.777
#
#
# Episode:             17
# Age:                 18947
# Current_time_s:      33.3
# CalledAccel_in_ms2:  -13.20121
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  35.838
# Action_%:            -72.311
# Reward:              -9.955
#
#
# Episode:             17
# Age:                 18948
# Current_time_s:      33.4
# CalledAccel_in_ms2:  -14.71689
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  34.806
# Action_%:            -79.157
# Reward:              -9.668
#
#
# Episode:             17
# Age:                 18949
# Current_time_s:      33.5
# CalledAccel_in_ms2:  -14.83656
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  37.055
# Action_%:            -79.689
# Reward:              -10.293
#
#
# Episode:             17
# Age:                 18950
# Current_time_s:      33.6
# CalledAccel_in_ms2:  -14.58293
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  37.075
# Action_%:            -78.56
# Reward:              -10.299
#
#
# Episode:             17
# Age:                 18951
# Current_time_s:      33.7
# CalledAccel_in_ms2:  -14.07288
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  41.305
# Action_%:            -76.273
# Reward:              -11.474
#
#
# Episode:             17
# Age:                 18952
# Current_time_s:      33.8
# CalledAccel_in_ms2:  -13.87648
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  37.405
# Action_%:            -75.387
# Reward:              -10.39
#
#
# Episode:             17
# Age:                 18953
# Current_time_s:      33.9
# CalledAccel_in_ms2:  -14.87143
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  40.39
# Action_%:            -79.844
# Reward:              -11.219
#
#
# Episode:             17
# Age:                 18954
# Current_time_s:      34.0
# CalledAccel_in_ms2:  -14.51986
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  36.701
# Action_%:            -78.279
# Reward:              -10.195
#
#
# Episode:             17
# Age:                 18955
# Current_time_s:      34.1
# CalledAccel_in_ms2:  -14.5418
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  40.748
# Action_%:            -78.377
# Reward:              -11.319
#
#
# Episode:             17
# Age:                 18956
# Current_time_s:      34.2
# CalledAccel_in_ms2:  -14.39747
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  41.177
# Action_%:            -77.731
# Reward:              -11.438
#
#
# Episode:             17
# Age:                 18957
# Current_time_s:      34.3
# CalledAccel_in_ms2:  -14.23013
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  43.656
# Action_%:            -76.981
# Reward:              -12.127
#
#
# Episode:             17
# Age:                 18958
# Current_time_s:      34.4
# CalledAccel_in_ms2:  -13.5661
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  36.191
# Action_%:            -73.978
# Reward:              -10.053
#
#
# Episode:             17
# Age:                 18959
# Current_time_s:      34.5
# CalledAccel_in_ms2:  -14.24893
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  44.083
# Action_%:            -77.065
# Reward:              -12.245
#
#
# Episode:             17
# Age:                 18960
# Current_time_s:      34.6
# CalledAccel_in_ms2:  -14.032
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  36.115
# Action_%:            -76.089
# Reward:              -10.032
#
#
# Episode:             17
# Age:                 18961
# Current_time_s:      34.7
# CalledAccel_in_ms2:  -13.311
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  40.16
# Action_%:            -72.814
# Reward:              -11.156
#
#
# Episode:             17
# Age:                 18962
# Current_time_s:      34.8
# CalledAccel_in_ms2:  -13.49597
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  39.143
# Action_%:            -73.659
# Reward:              -10.873
#
#
# Episode:             17
# Age:                 18963
# Current_time_s:      34.9
# CalledAccel_in_ms2:  -13.25572
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  40.935
# Action_%:            -72.561
# Reward:              -11.371
#
#
# Episode:             17
# Age:                 18964
# Current_time_s:      35.0
# CalledAccel_in_ms2:  -13.53114
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  39.661
# Action_%:            -73.819
# Reward:              -11.017
#
#
# Episode:             17
# Age:                 18965
# Current_time_s:      35.1
# CalledAccel_in_ms2:  -12.86282
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  37.849
# Action_%:            -70.753
# Reward:              -10.514
#
#
# Episode:             17
# Age:                 18966
# Current_time_s:      35.2
# CalledAccel_in_ms2:  -12.25929
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  36.248
# Action_%:            -67.947
# Reward:              -10.069
#
#
# Episode:             17
# Age:                 18967
# Current_time_s:      35.3
# CalledAccel_in_ms2:  -12.88413
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  36.367
# Action_%:            -70.851
# Reward:              -10.102
#
#
# Episode:             17
# Age:                 18968
# Current_time_s:      35.4
# CalledAccel_in_ms2:  -13.30776
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  41.411
# Action_%:            -72.799
# Reward:              -11.503
#
#
# Episode:             17
# Age:                 18969
# Current_time_s:      35.5
# CalledAccel_in_ms2:  -13.37672
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  44.292
# Action_%:            -73.114
# Reward:              -12.303
#
#
# Episode:             17
# Age:                 18970
# Current_time_s:      35.6
# CalledAccel_in_ms2:  -13.68428
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  37.538
# Action_%:            -74.515
# Reward:              -10.427
#
#
# Episode:             17
# Age:                 18971
# Current_time_s:      35.7
# CalledAccel_in_ms2:  -13.44216
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  43.77
# Action_%:            -73.413
# Reward:              -12.158
#
#
# Episode:             17
# Age:                 18972
# Current_time_s:      35.8
# CalledAccel_in_ms2:  -13.31678
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  39.319
# Action_%:            -72.84
# Reward:              -10.922
#
#
# Episode:             17
# Age:                 18973
# Current_time_s:      35.9
# CalledAccel_in_ms2:  -13.13271
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  37.01
# Action_%:            -71.996
# Reward:              -10.281
#
#
# Episode:             17
# Age:                 18974
# Current_time_s:      36.0
# CalledAccel_in_ms2:  -13.75116
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  39.471
# Action_%:            -74.819
# Reward:              -10.964
#
#
# Episode:             17
# Age:                 18975
# Current_time_s:      36.1
# CalledAccel_in_ms2:  -12.93361
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  43.102
# Action_%:            -71.08
# Reward:              -11.973
#
#
# Episode:             17
# Age:                 18976
# Current_time_s:      36.2
# CalledAccel_in_ms2:  -13.18566
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  37.143
# Action_%:            -72.239
# Reward:              -10.318
#
#
# Episode:             17
# Age:                 18977
# Current_time_s:      36.3
# CalledAccel_in_ms2:  -12.83164
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  44.524
# Action_%:            -70.609
# Reward:              -12.368
#
#
# Episode:             17
# Age:                 18978
# Current_time_s:      36.4
# CalledAccel_in_ms2:  -12.14978
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  37.837
# Action_%:            -67.435
# Reward:              -10.51
#
#
# Episode:             17
# Age:                 18979
# Current_time_s:      36.5
# CalledAccel_in_ms2:  -11.86305
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  42.346
# Action_%:            -66.086
# Reward:              -11.763
#
#
# Episode:             17
# Age:                 18980
# Current_time_s:      36.6
# CalledAccel_in_ms2:  -11.74005
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  36.779
# Action_%:            -65.504
# Reward:              -10.216
#
#
# Episode:             17
# Age:                 18981
# Current_time_s:      36.7
# CalledAccel_in_ms2:  -12.08871
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  38.334
# Action_%:            -67.148
# Reward:              -10.648
#
#
# Episode:             17
# Age:                 18982
# Current_time_s:      36.8
# CalledAccel_in_ms2:  -12.20036
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  39.902
# Action_%:            -67.672
# Reward:              -11.084
#
#
# Episode:             17
# Age:                 18983
# Current_time_s:      36.9
# CalledAccel_in_ms2:  -12.99628
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  37.377
# Action_%:            -71.369
# Reward:              -10.383
#
#
# Episode:             17
# Age:                 18984
# Current_time_s:      37.0
# CalledAccel_in_ms2:  -13.00355
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  42.616
# Action_%:            -71.402
# Reward:              -11.838
#
#
# Episode:             17
# Age:                 18985
# Current_time_s:      37.1
# CalledAccel_in_ms2:  -11.9013
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  34.24
# Action_%:            -66.266
# Reward:              -9.511
#
#
# Episode:             17
# Age:                 18986
# Current_time_s:      37.2
# CalledAccel_in_ms2:  -10.93382
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  36.883
# Action_%:            -61.655
# Reward:              -10.245
#
#
# Episode:             17
# Age:                 18987
# Current_time_s:      37.3
# CalledAccel_in_ms2:  -10.83378
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  42.763
# Action_%:            -61.173
# Reward:              -11.879
#
#
# Episode:             17
# Age:                 18988
# Current_time_s:      37.4
# CalledAccel_in_ms2:  -10.81823
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  37.078
# Action_%:            -61.098
# Reward:              -10.299
#
#
# Episode:             17
# Age:                 18989
# Current_time_s:      37.5
# CalledAccel_in_ms2:  -10.73157
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  43.284
# Action_%:            -60.679
# Reward:              -12.023
#
#
# Episode:             17
# Age:                 18990
# Current_time_s:      37.6
# CalledAccel_in_ms2:  -9.62883
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  44.957
# Action_%:            -55.272
# Reward:              -12.488
#
#
# Episode:             17
# Age:                 18991
# Current_time_s:      37.7
# CalledAccel_in_ms2:  -10.22148
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  41.688
# Action_%:            -58.195
# Reward:              -11.58
#
#
# Episode:             17
# Age:                 18992
# Current_time_s:      37.8
# CalledAccel_in_ms2:  -10.80295
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  38.144
# Action_%:            -61.024
# Reward:              -10.595
#
#
# Episode:             17
# Age:                 18993
# Current_time_s:      37.9
# CalledAccel_in_ms2:  -10.42849
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  43.006
# Action_%:            -59.207
# Reward:              -11.946
#
#
# Episode:             17
# Age:                 18994
# Current_time_s:      38.0
# CalledAccel_in_ms2:  -10.74625
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  39.096
# Action_%:            -60.75
# Reward:              -10.86
#
#
# Episode:             17
# Age:                 18995
# Current_time_s:      38.1
# CalledAccel_in_ms2:  -11.17144
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  43.708
# Action_%:            -62.797
# Reward:              -12.141
#
#
# Episode:             17
# Age:                 18996
# Current_time_s:      38.2
# CalledAccel_in_ms2:  -10.21158
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  42.352
# Action_%:            -58.147
# Reward:              -11.764
#
#
# Episode:             17
# Age:                 18997
# Current_time_s:      38.3
# CalledAccel_in_ms2:  -10.49777
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  37.239
# Action_%:            -59.544
# Reward:              -10.344
#
#
# Episode:             17
# Age:                 18998
# Current_time_s:      38.4
# CalledAccel_in_ms2:  -10.47584
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  35.274
# Action_%:            -59.437
# Reward:              -9.798
#
#
# Episode:             17
# Age:                 18999
# Current_time_s:      38.5
# CalledAccel_in_ms2:  -9.59439
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  39.313
# Action_%:            -55.101
# Reward:              -10.92
#
#
# Episode:             17
# Age:                 19000
# Current_time_s:      38.6
# CalledAccel_in_ms2:  -10.69208
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  43.799
# Action_%:            -60.488
# Reward:              -12.167
#
#
# Episode:             17
# Age:                 19001
# Current_time_s:      38.7
# CalledAccel_in_ms2:  -11.63966
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  43.802
# Action_%:            -65.029
# Reward:              -12.167
#
#
# Episode:             17
# Age:                 19002
# Current_time_s:      38.8
# CalledAccel_in_ms2:  -12.04935
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  38.46
# Action_%:            -66.963
# Reward:              -10.683
#
#
# Episode:             17
# Age:                 19003
# Current_time_s:      38.9
# CalledAccel_in_ms2:  -11.83624
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  41.939
# Action_%:            -65.959
# Reward:              -11.65
#
#
# Episode:             17
# Age:                 19004
# Current_time_s:      39.0
# CalledAccel_in_ms2:  -11.74645
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  39.251
# Action_%:            -65.535
# Reward:              -10.903
#
#
# Episode:             17
# Age:                 19005
# Current_time_s:      39.1
# CalledAccel_in_ms2:  -12.03147
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  35.273
# Action_%:            -66.879
# Reward:              -9.798
#
#
# Episode:             17
# Age:                 19006
# Current_time_s:      39.2
# CalledAccel_in_ms2:  -11.71865
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  37.299
# Action_%:            -65.403
# Reward:              -10.361
#
#
# Episode:             17
# Age:                 19007
# Current_time_s:      39.3
# CalledAccel_in_ms2:  -11.81294
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  36.839
# Action_%:            -65.849
# Reward:              -10.233
#
#
# Episode:             17
# Age:                 19008
# Current_time_s:      39.4
# CalledAccel_in_ms2:  -12.53064
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  41.826
# Action_%:            -69.213
# Reward:              -11.618
#
#
# Episode:             17
# Age:                 19009
# Current_time_s:      39.5
# CalledAccel_in_ms2:  -12.46486
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  37.935
# Action_%:            -68.907
# Reward:              -10.537
#
#
# Episode:             17
# Age:                 19010
# Current_time_s:      39.6
# CalledAccel_in_ms2:  -11.42632
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  43.453
# Action_%:            -64.015
# Reward:              -12.07
#
#
# Episode:             17
# Age:                 19011
# Current_time_s:      39.7
# CalledAccel_in_ms2:  -10.66441
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  42.04
# Action_%:            -60.353
# Reward:              -11.678
#
#
# Episode:             17
# Age:                 19012
# Current_time_s:      39.8
# CalledAccel_in_ms2:  -11.97559
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  37.485
# Action_%:            -66.616
# Reward:              -10.413
#
#
# Episode:             17
# Age:                 19013
# Current_time_s:      39.9
# CalledAccel_in_ms2:  -11.49009
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  34.95
# Action_%:            -64.319
# Reward:              -9.708
#
#
# Episode:             17
# Age:                 19014
# Current_time_s:      40.0
# CalledAccel_in_ms2:  -11.48474
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  43.915
# Action_%:            -64.293
# Reward:              -12.199
#
#
# Episode:             17
# Age:                 19015
# Current_time_s:      40.1
# CalledAccel_in_ms2:  -11.56409
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  34.46
# Action_%:            -64.67
# Reward:              -9.572
#
#
# Episode:             17
# Age:                 19016
# Current_time_s:      40.2
# CalledAccel_in_ms2:  -12.04317
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  37.186
# Action_%:            -66.934
# Reward:              -10.329
#
#
# Episode:             17
# Age:                 19017
# Current_time_s:      40.3
# CalledAccel_in_ms2:  -10.58138
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  42.943
# Action_%:            -59.951
# Reward:              -11.929
#
#
# Episode:             17
# Age:                 19018
# Current_time_s:      40.4
# CalledAccel_in_ms2:  -12.04412
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  39.699
# Action_%:            -66.938
# Reward:              -11.027
#
#
# Episode:             17
# Age:                 19019
# Current_time_s:      40.5
# CalledAccel_in_ms2:  -11.77369
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  38.747
# Action_%:            -65.664
# Reward:              -10.763
#
#
# Episode:             17
# Age:                 19020
# Current_time_s:      40.6
# CalledAccel_in_ms2:  -11.44325
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  44.043
# Action_%:            -64.096
# Reward:              -12.234
#
#
# Episode:             17
# Age:                 19021
# Current_time_s:      40.7
# CalledAccel_in_ms2:  -12.20391
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  36.223
# Action_%:            -67.688
# Reward:              -10.062
#
#
# Episode:             17
# Age:                 19022
# Current_time_s:      40.8
# CalledAccel_in_ms2:  -12.78779
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  37.403
# Action_%:            -70.406
# Reward:              -10.39
#
#
# Episode:             17
# Age:                 19023
# Current_time_s:      40.9
# CalledAccel_in_ms2:  -13.87142
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  44.403
# Action_%:            -75.364
# Reward:              -12.334
#
#
# Episode:             17
# Age:                 19024
# Current_time_s:      41.0
# CalledAccel_in_ms2:  -13.81932
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  36.988
# Action_%:            -75.128
# Reward:              -10.275
#
#
# Episode:             17
# Age:                 19025
# Current_time_s:      41.1
# CalledAccel_in_ms2:  -13.70791
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  37.798
# Action_%:            -74.623
# Reward:              -10.499
#
#
# Episode:             17
# Age:                 19026
# Current_time_s:      41.2
# CalledAccel_in_ms2:  -14.41499
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  42.811
# Action_%:            -77.81
# Reward:              -11.892
#
#
# Episode:             17
# Age:                 19027
# Current_time_s:      41.3
# CalledAccel_in_ms2:  -15.08453
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  42.841
# Action_%:            -80.787
# Reward:              -11.9
#
#
# Episode:             17
# Age:                 19028
# Current_time_s:      41.4
# CalledAccel_in_ms2:  -16.20345
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  35.418
# Action_%:            -85.679
# Reward:              -9.838
#
#
# Episode:             17
# Age:                 19029
# Current_time_s:      41.5
# CalledAccel_in_ms2:  -16.42747
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  43.122
# Action_%:            -86.646
# Reward:              -11.978
#
#
# Episode:             17
# Age:                 19030
# Current_time_s:      41.6
# CalledAccel_in_ms2:  -17.44229
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  42.768
# Action_%:            -90.979
# Reward:              -11.88
#
#
# Episode:             17
# Age:                 19031
# Current_time_s:      41.7
# CalledAccel_in_ms2:  -18.1025
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  38.012
# Action_%:            -93.757
# Reward:              -10.559
#
#
# Episode:             17
# Age:                 19032
# Current_time_s:      41.8
# CalledAccel_in_ms2:  -18.28796
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  41.71
# Action_%:            -94.532
# Reward:              -11.586
#
#
# Episode:             17
# Age:                 19033
# Current_time_s:      41.9
# CalledAccel_in_ms2:  -18.17776
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  37.792
# Action_%:            -94.072
# Reward:              -10.498
#
#
# Episode:             17
# Age:                 19034
# Current_time_s:      42.0
# CalledAccel_in_ms2:  -17.38818
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  44.098
# Action_%:            -90.75
# Reward:              -12.25
#
#
# Episode:             17
# Age:                 19035
# Current_time_s:      42.1
# CalledAccel_in_ms2:  -17.53803
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  40.656
# Action_%:            -91.384
# Reward:              -11.293
#
#
# Episode:             17
# Age:                 19036
# Current_time_s:      42.2
# CalledAccel_in_ms2:  -15.98939
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  42.716
# Action_%:            -84.751
# Reward:              -11.865
#
#
# Episode:             17
# Age:                 19037
# Current_time_s:      42.3
# CalledAccel_in_ms2:  -15.54166
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  37.841
# Action_%:            -82.798
# Reward:              -10.511
#
#
# Episode:             17
# Age:                 19038
# Current_time_s:      42.4
# CalledAccel_in_ms2:  -15.13417
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  40.904
# Action_%:            -81.007
# Reward:              -11.362
#
#
# Episode:             17
# Age:                 19039
# Current_time_s:      42.5
# CalledAccel_in_ms2:  -16.16838
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  42.216
# Action_%:            -85.527
# Reward:              -11.727
#
#
# Episode:             17
# Age:                 19040
# Current_time_s:      42.6
# CalledAccel_in_ms2:  -15.08218
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  38.076
# Action_%:            -80.777
# Reward:              -10.577
#
#
# Episode:             17
# Age:                 19041
# Current_time_s:      42.7
# CalledAccel_in_ms2:  -15.71001
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  43.617
# Action_%:            -83.534
# Reward:              -12.116
#
#
# Episode:             17
# Age:                 19042
# Current_time_s:      42.8
# CalledAccel_in_ms2:  -15.48664
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  36.122
# Action_%:            -82.557
# Reward:              -10.034
#
#
# Episode:             17
# Age:                 19043
# Current_time_s:      42.9
# CalledAccel_in_ms2:  -15.49228
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  40.347
# Action_%:            -82.582
# Reward:              -11.207
#
#
# Episode:             17
# Age:                 19044
# Current_time_s:      43.0
# CalledAccel_in_ms2:  -15.17869
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  38.349
# Action_%:            -81.203
# Reward:              -10.653
#
#
# Episode:             17
# Age:                 19045
# Current_time_s:      43.1
# CalledAccel_in_ms2:  -15.85778
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  37.314
# Action_%:            -84.179
# Reward:              -10.365
#
#
# Episode:             17
# Age:                 19046
# Current_time_s:      43.2
# CalledAccel_in_ms2:  -16.43171
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  36.163
# Action_%:            -86.665
# Reward:              -10.045
#
#
# Episode:             17
# Age:                 19047
# Current_time_s:      43.3
# CalledAccel_in_ms2:  -16.16408
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  37.594
# Action_%:            -85.509
# Reward:              -10.443
#
#
# Episode:             17
# Age:                 19048
# Current_time_s:      43.4
# CalledAccel_in_ms2:  -17.39213
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  36.79
# Action_%:            -90.767
# Reward:              -10.219
#
#
# Episode:             17
# Age:                 19049
# Current_time_s:      43.5
# CalledAccel_in_ms2:  -19.08796
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  38.27
# Action_%:            -97.845
# Reward:              -10.631
#
#
# Episode:             17
# Age:                 19050
# Current_time_s:      43.6
# CalledAccel_in_ms2:  -19.22384
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  36.25
# Action_%:            -98.404
# Reward:              -10.069
#
#
# Episode:             17
# Age:                 19051
# Current_time_s:      43.7
# CalledAccel_in_ms2:  -18.78866
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  44.326
# Action_%:            -96.611
# Reward:              -12.313
#
#
# Episode:             17
# Age:                 19052
# Current_time_s:      43.8
# CalledAccel_in_ms2:  -19.23066
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  39.323
# Action_%:            -98.432
# Reward:              -10.923
#
#
# Episode:             17
# Age:                 19053
# Current_time_s:      43.9
# CalledAccel_in_ms2:  -19.24724
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  36.721
# Action_%:            -98.5
# Reward:              -10.2
#
#
# Episode:             17
# Age:                 19054
# Current_time_s:      44.0
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  41.959
# Action_%:            -100.0
# Reward:              -11.655
#
#
# Episode:             17
# Age:                 19055
# Current_time_s:      44.1
# CalledAccel_in_ms2:  -19.31001
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  40.592
# Action_%:            -98.757
# Reward:              -11.275
#
#
# Episode:             17
# Age:                 19056
# Current_time_s:      44.2
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  43.07
# Action_%:            -100.0
# Reward:              -11.964
#
#
# Episode:             17
# Age:                 19057
# Current_time_s:      44.3
# CalledAccel_in_ms2:  -19.22434
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  42.863
# Action_%:            -98.406
# Reward:              -11.906
#
#
# Episode:             17
# Age:                 19058
# Current_time_s:      44.4
# CalledAccel_in_ms2:  -19.47953
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  43.369
# Action_%:            -99.451
# Reward:              -12.047
#
#
# Episode:             17
# Age:                 19059
# Current_time_s:      44.5
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  36.767
# Action_%:            -100.0
# Reward:              -10.213
#
#
# Episode:             17
# Age:                 19060
# Current_time_s:      44.6
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  37.742
# Action_%:            -100.0
# Reward:              -10.484
#
#
# Episode:             17
# Age:                 19061
# Current_time_s:      44.7
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  36.137
# Action_%:            -100.0
# Reward:              -10.038
#
#
# Episode:             17
# Age:                 19062
# Current_time_s:      44.8
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  38.44
# Action_%:            -100.0
# Reward:              -10.678
#
#
# Episode:             17
# Age:                 19063
# Current_time_s:      44.9
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  34.248
# Action_%:            -100.0
# Reward:              -9.513
#
#
# Episode:             17
# Age:                 19064
# Current_time_s:      45.0
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  37.66
# Action_%:            -100.0
# Reward:              -10.461
#
#
# Episode:             17
# Age:                 19065
# Current_time_s:      45.1
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  41.189
# Action_%:            -100.0
# Reward:              -11.441
#
#
# Episode:             17
# Age:                 19066
# Current_time_s:      45.2
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  36.25
# Action_%:            -100.0
# Reward:              -10.069
#
#
# Episode:             17
# Age:                 19067
# Current_time_s:      45.3
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  40.166
# Action_%:            -100.0
# Reward:              -11.157
#
#
# Episode:             17
# Age:                 19068
# Current_time_s:      45.4
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  38.912
# Action_%:            -100.0
# Reward:              -10.809
#
#
# Episode:             17
# Age:                 19069
# Current_time_s:      45.5
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  38.938
# Action_%:            -100.0
# Reward:              -10.816
#
#
# Episode:             17
# Age:                 19070
# Current_time_s:      45.6
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  35.874
# Action_%:            -100.0
# Reward:              -9.965
#
#
# Episode:             17
# Age:                 19071
# Current_time_s:      45.7
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  37.103
# Action_%:            -100.0
# Reward:              -10.306
#
#
# Episode:             17
# Age:                 19072
# Current_time_s:      45.8
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  38.175
# Action_%:            -100.0
# Reward:              -10.604
#
#
# Episode:             17
# Age:                 19073
# Current_time_s:      45.9
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  39.953
# Action_%:            -100.0
# Reward:              -11.098
#
#
# Episode:             17
# Age:                 19074
# Current_time_s:      46.0
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  43.769
# Action_%:            -100.0
# Reward:              -12.158
#
#
# Episode:             17
# Age:                 19075
# Current_time_s:      46.1
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  41.908
# Action_%:            -100.0
# Reward:              -11.641
#
#
# Episode:             17
# Age:                 19076
# Current_time_s:      46.2
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  43.853
# Action_%:            -100.0
# Reward:              -12.181
#
#
# Episode:             17
# Age:                 19077
# Current_time_s:      46.3
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  41.109
# Action_%:            -100.0
# Reward:              -11.419
#
#
# Episode:             17
# Age:                 19078
# Current_time_s:      46.4
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  35.007
# Action_%:            -100.0
# Reward:              -9.724
#
#
# Episode:             17
# Age:                 19079
# Current_time_s:      46.5
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  43.271
# Action_%:            -100.0
# Reward:              -12.02
#
#
# Episode:             17
# Age:                 19080
# Current_time_s:      46.6
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  38.724
# Action_%:            -100.0
# Reward:              -10.757
#
#
# Episode:             17
# Age:                 19081
# Current_time_s:      46.7
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  35.826
# Action_%:            -100.0
# Reward:              -9.952
#
#
# Episode:             17
# Age:                 19082
# Current_time_s:      46.8
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  44.194
# Action_%:            -100.0
# Reward:              -12.276
#
#
# Episode:             17
# Age:                 19083
# Current_time_s:      46.9
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  42.09
# Action_%:            -100.0
# Reward:              -11.692
#
#
# Episode:             17
# Age:                 19084
# Current_time_s:      47.0
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  41.916
# Action_%:            -100.0
# Reward:              -11.643
#
#
# Episode:             17
# Age:                 19085
# Current_time_s:      47.1
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  37.607
# Action_%:            -100.0
# Reward:              -10.446
#
#
# Episode:             17
# Age:                 19086
# Current_time_s:      47.2
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  41.125
# Action_%:            -100.0
# Reward:              -11.424
#
#
# Episode:             17
# Age:                 19087
# Current_time_s:      47.3
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  43.567
# Action_%:            -100.0
# Reward:              -12.102
#
#
# Episode:             17
# Age:                 19088
# Current_time_s:      47.4
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  40.103
# Action_%:            -100.0
# Reward:              -11.14
#
#
# Episode:             17
# Age:                 19089
# Current_time_s:      47.5
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  36.264
# Action_%:            -100.0
# Reward:              -10.073
#
#
# Episode:             17
# Age:                 19090
# Current_time_s:      47.6
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  35.266
# Action_%:            -100.0
# Reward:              -9.796
#
#
# Episode:             17
# Age:                 19091
# Current_time_s:      47.7
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  41.341
# Action_%:            -100.0
# Reward:              -11.484
#
#
# Episode:             17
# Age:                 19092
# Current_time_s:      47.8
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  44.182
# Action_%:            -100.0
# Reward:              -12.273
#
#
# Episode:             17
# Age:                 19093
# Current_time_s:      47.9
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  43.229
# Action_%:            -100.0
# Reward:              -12.008
#
#
# Episode:             17
# Age:                 19094
# Current_time_s:      48.0
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  35.225
# Action_%:            -100.0
# Reward:              -9.785
#
#
# Episode:             17
# Age:                 19095
# Current_time_s:      48.1
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  41.982
# Action_%:            -100.0
# Reward:              -11.662
#
#
# Episode:             17
# Age:                 19096
# Current_time_s:      48.2
# CalledAccel_in_ms2:  -19.60957
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  41.53
# Action_%:            -99.982
# Reward:              -11.536
#
#
# Episode:             17
# Age:                 19097
# Current_time_s:      48.3
# CalledAccel_in_ms2:  -19.35862
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  38.636
# Action_%:            -98.956
# Reward:              -10.732
#
#
# Episode:             17
# Age:                 19098
# Current_time_s:      48.4
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  38.577
# Action_%:            -100.0
# Reward:              -10.716
#
#
# Episode:             17
# Age:                 19099
# Current_time_s:      48.5
# CalledAccel_in_ms2:  -18.44046
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  40.538
# Action_%:            -95.167
# Reward:              -11.261
#
#
# Episode:             17
# Age:                 19100
# Current_time_s:      48.6
# CalledAccel_in_ms2:  -18.88824
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  40.536
# Action_%:            -97.022
# Reward:              -11.26
#
#
# Episode:             17
# Age:                 19101
# Current_time_s:      48.7
# CalledAccel_in_ms2:  -18.18899
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  35.778
# Action_%:            -94.119
# Reward:              -9.938
#
#
# Episode:             17
# Age:                 19102
# Current_time_s:      48.8
# CalledAccel_in_ms2:  -18.61947
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  34.595
# Action_%:            -95.91
# Reward:              -9.61
#
#
# Episode:             17
# Age:                 19103
# Current_time_s:      48.9
# CalledAccel_in_ms2:  -18.09868
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  36.721
# Action_%:            -93.741
# Reward:              -10.2
#
#
# Episode:             17
# Age:                 19104
# Current_time_s:      49.0
# CalledAccel_in_ms2:  -18.03931
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  36.455
# Action_%:            -93.493
# Reward:              -10.127
#
#
# Episode:             17
# Age:                 19105
# Current_time_s:      49.1
# CalledAccel_in_ms2:  -18.65954
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  44.82
# Action_%:            -96.076
# Reward:              -12.45
#
#
# Episode:             17
# Age:                 19106
# Current_time_s:      49.2
# CalledAccel_in_ms2:  -19.30501
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  41.828
# Action_%:            -98.737
# Reward:              -11.619
#
#
# Episode:             17
# Age:                 19107
# Current_time_s:      49.3
# CalledAccel_in_ms2:  -19.23774
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  41.959
# Action_%:            -98.461
# Reward:              -11.655
#
#
# Episode:             17
# Age:                 19108
# Current_time_s:      49.4
# CalledAccel_in_ms2:  -18.97815
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  37.775
# Action_%:            -97.393
# Reward:              -10.493
#
#
# Episode:             17
# Age:                 19109
# Current_time_s:      49.5
# CalledAccel_in_ms2:  -18.54824
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  36.096
# Action_%:            -95.615
# Reward:              -10.027
#
#
# Episode:             17
# Age:                 19110
# Current_time_s:      49.6
# CalledAccel_in_ms2:  -19.48849
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  38.103
# Action_%:            -99.488
# Reward:              -10.584
#
#
# Episode:             17
# Age:                 19111
# Current_time_s:      49.7
# CalledAccel_in_ms2:  -18.31579
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  38.853
# Action_%:            -94.648
# Reward:              -10.793
#
#
# Episode:             17
# Age:                 19112
# Current_time_s:      49.8
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  43.272
# Action_%:            -100.0
# Reward:              -12.02
#
#
# Episode:             17
# Age:                 19113
# Current_time_s:      49.9
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  37.583
# Action_%:            -100.0
# Reward:              -10.44
#
#
# Episode:             17
# Age:                 19114
# Current_time_s:      50.0
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  38.619
# Action_%:            -100.0
# Reward:              -10.727
#
#
# Episode:             17
# Age:                 19115
# Current_time_s:      50.1
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  38.217
# Action_%:            -100.0
# Reward:              -10.616
#
#
# Episode:             17
# Age:                 19116
# Current_time_s:      50.2
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  40.073
# Action_%:            -100.0
# Reward:              -11.131
#
#
# Episode:             17
# Age:                 19117
# Current_time_s:      50.3
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  40.705
# Action_%:            -100.0
# Reward:              -11.307
#
#
# Episode:             17
# Age:                 19118
# Current_time_s:      50.4
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  38.29
# Action_%:            -100.0
# Reward:              -10.636
#
#
# Episode:             17
# Age:                 19119
# Current_time_s:      50.5
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  42.652
# Action_%:            -100.0
# Reward:              -11.848
#
#
# Episode:             17
# Age:                 19120
# Current_time_s:      50.6
# CalledAccel_in_ms2:  -19.44246
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  39.356
# Action_%:            -99.299
# Reward:              -10.932
#
#
# Episode:             17
# Age:                 19121
# Current_time_s:      50.7
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  44.887
# Action_%:            -100.0
# Reward:              -12.469
#
#
# Episode:             17
# Age:                 19122
# Current_time_s:      50.8
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  43.637
# Action_%:            -100.0
# Reward:              -12.121
#
#
# Episode:             17
# Age:                 19123
# Current_time_s:      50.9
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  41.337
# Action_%:            -100.0
# Reward:              -11.482
#
#
# Episode:             17
# Age:                 19124
# Current_time_s:      51.0
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  44.928
# Action_%:            -100.0
# Reward:              -12.48
#
#
# Episode:             17
# Age:                 19125
# Current_time_s:      51.1
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  38.534
# Action_%:            -100.0
# Reward:              -10.704
#
#
# Episode:             17
# Age:                 19126
# Current_time_s:      51.2
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  43.387
# Action_%:            -100.0
# Reward:              -12.052
#
#
# Episode:             17
# Age:                 19127
# Current_time_s:      51.3
# CalledAccel_in_ms2:  -19.614
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  39.539
# Action_%:            -100.0
# Reward:              -10.983
#
#
# Episode:             17
# Age:                 19128
# Current_time_s:      51.4
# CalledAccel_in_ms2:  -18.60026
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  35.18
# Action_%:            -95.83
# Reward:              -9.772
#
#
# Episode:             17
# Age:                 19129
# Current_time_s:      51.5
# CalledAccel_in_ms2:  -18.17183
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  41.3
# Action_%:            -94.047
# Reward:              -11.472
#
#
# Episode:             17
# Age:                 19130
# Current_time_s:      51.6
# CalledAccel_in_ms2:  -17.43745
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  37.865
# Action_%:            -90.959
# Reward:              -10.518
#
#
# Episode:             17
# Age:                 19131
# Current_time_s:      51.7
# CalledAccel_in_ms2:  -18.42059
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  41.982
# Action_%:            -95.084
# Reward:              -11.662
#
#
# Episode:             17
# Age:                 19132
# Current_time_s:      51.8
# CalledAccel_in_ms2:  -18.57788
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  42.364
# Action_%:            -95.738
# Reward:              -11.768
#
#
# Episode:             17
# Age:                 19133
# Current_time_s:      51.9
# CalledAccel_in_ms2:  -18.42427
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  38.639
# Action_%:            -95.099
# Reward:              -10.733
#
#
# Episode:             17
# Age:                 19134
# Current_time_s:      52.0
# CalledAccel_in_ms2:  -18.05204
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  35.646
# Action_%:            -93.546
# Reward:              -9.902
#
#
# Episode:             17
# Age:                 19135
# Current_time_s:      52.1
# CalledAccel_in_ms2:  -18.02853
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  42.439
# Action_%:            -93.447
# Reward:              -11.789
#
#
# Episode:             17
# Age:                 19136
# Current_time_s:      52.2
# CalledAccel_in_ms2:  -17.9228
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  36.891
# Action_%:            -93.004
# Reward:              -10.247
#
#
# Episode:             17
# Age:                 19137
# Current_time_s:      52.3
# CalledAccel_in_ms2:  -16.60926
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  43.039
# Action_%:            -87.428
# Reward:              -11.955
#
#
# Episode:             17
# Age:                 19138
# Current_time_s:      52.4
# CalledAccel_in_ms2:  -15.64322
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  42.436
# Action_%:            -83.243
# Reward:              -11.788
#
#
# Episode:             17
# Age:                 19139
# Current_time_s:      52.5
# CalledAccel_in_ms2:  -15.54333
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  37.37
# Action_%:            -82.806
# Reward:              -10.381
#
#
# Episode:             17
# Age:                 19140
# Current_time_s:      52.6
# CalledAccel_in_ms2:  -15.33979
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  41.386
# Action_%:            -81.912
# Reward:              -11.496
#
#
# Episode:             17
# Age:                 19141
# Current_time_s:      52.7
# CalledAccel_in_ms2:  -13.72391
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  35.73
# Action_%:            -74.695
# Reward:              -9.925
#
#
# Episode:             17
# Age:                 19142
# Current_time_s:      52.8
# CalledAccel_in_ms2:  -14.15334
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  39.318
# Action_%:            -76.636
# Reward:              -10.922
#
#
# Episode:             17
# Age:                 19143
# Current_time_s:      52.9
# CalledAccel_in_ms2:  -13.40645
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  43.224
# Action_%:            -73.25
# Reward:              -12.007
#
#
# Episode:             17
# Age:                 19144
# Current_time_s:      53.0
# CalledAccel_in_ms2:  -13.18253
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  38.653
# Action_%:            -72.225
# Reward:              -10.737
#
#
# Episode:             17
# Age:                 19145
# Current_time_s:      53.1
# CalledAccel_in_ms2:  -11.62205
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  41.429
# Action_%:            -64.945
# Reward:              -11.508
#
#
# Episode:             17
# Age:                 19146
# Current_time_s:      53.2
# CalledAccel_in_ms2:  -10.57336
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  42.711
# Action_%:            -59.912
# Reward:              -11.864
#
#
# Episode:             17
# Age:                 19147
# Current_time_s:      53.3
# CalledAccel_in_ms2:  -10.06674
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  35.306
# Action_%:            -57.436
# Reward:              -9.807
#
#
# Episode:             17
# Age:                 19148
# Current_time_s:      53.4
# CalledAccel_in_ms2:  -11.21209
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  44.952
# Action_%:            -62.992
# Reward:              -12.487
#
#
# Episode:             17
# Age:                 19149
# Current_time_s:      53.5
# CalledAccel_in_ms2:  -11.47748
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  40.476
# Action_%:            -64.259
# Reward:              -11.243
#
#
# Episode:             17
# Age:                 19150
# Current_time_s:      53.6
# CalledAccel_in_ms2:  -12.66648
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  38.299
# Action_%:            -69.844
# Reward:              -10.639
#
#
# Episode:             17
# Age:                 19151
# Current_time_s:      53.7
# CalledAccel_in_ms2:  -12.82117
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  43.127
# Action_%:            -70.561
# Reward:              -11.98
#
#
# Episode:             17
# Age:                 19152
# Current_time_s:      53.8
# CalledAccel_in_ms2:  -13.1341
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  36.153
# Action_%:            -72.003
# Reward:              -10.042
#
#
# Episode:             17
# Age:                 19153
# Current_time_s:      53.9
# CalledAccel_in_ms2:  -14.16213
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  35.762
# Action_%:            -76.675
# Reward:              -9.934
#
#
# Episode:             17
# Age:                 19154
# Current_time_s:      54.0
# CalledAccel_in_ms2:  -15.01348
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  40.54
# Action_%:            -80.473
# Reward:              -11.261
#
#
# Episode:             17
# Age:                 19155
# Current_time_s:      54.1
# CalledAccel_in_ms2:  -15.33521
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  36.244
# Action_%:            -81.892
# Reward:              -10.068
#
#
# Episode:             17
# Age:                 19156
# Current_time_s:      54.2
# CalledAccel_in_ms2:  -15.34698
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  35.658
# Action_%:            -81.944
# Reward:              -9.905
#
#
# Episode:             17
# Age:                 19157
# Current_time_s:      54.3
# CalledAccel_in_ms2:  -16.23874
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  39.268
# Action_%:            -85.832
# Reward:              -10.908
#
#
# Episode:             17
# Age:                 19158
# Current_time_s:      54.4
# CalledAccel_in_ms2:  -15.80805
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  39.611
# Action_%:            -83.962
# Reward:              -11.003
#
#
# Episode:             17
# Age:                 19159
# Current_time_s:      54.5
# CalledAccel_in_ms2:  -15.61124
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  36.134
# Action_%:            -83.103
# Reward:              -10.037
#
#
# Episode:             17
# Age:                 19160
# Current_time_s:      54.6
# CalledAccel_in_ms2:  -15.01109
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  34.901
# Action_%:            -80.463
# Reward:              -9.695
#
#
# Episode:             17
# Age:                 19161
# Current_time_s:      54.7
# CalledAccel_in_ms2:  -15.25038
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  36.268
# Action_%:            -81.519
# Reward:              -10.075
#
#
# Episode:             17
# Age:                 19162
# Current_time_s:      54.8
# CalledAccel_in_ms2:  -15.37154
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  34.266
# Action_%:            -82.052
# Reward:              -9.518
#
#
# ...
# Current_time_s:      76.8
# CalledAccel_in_ms2:  -18.73268
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  38.736
# Action_%:            -96.379
# Reward:              -10.76
#
#
# Episode:             17
# Age:                 19383
# Current_time_s:      76.9
# CalledAccel_in_ms2:  -17.82711
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  34.649
# Action_%:            -92.602
# Reward:              -9.625
#
#
# Episode:             17
# Age:                 19384
# Current_time_s:      77.0
# CalledAccel_in_ms2:  -16.97207
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  44.195
# Action_%:            -88.982
# Reward:              -12.276
#
#
# Episode:             17
# Age:                 19385
# Current_time_s:      77.1
# CalledAccel_in_ms2:  -17.48287
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  37.794
# Action_%:            -91.151
# Reward:              -10.498
#
#
# Episode:             17
# Age:                 19386
# Current_time_s:      77.2
# CalledAccel_in_ms2:  -17.81234
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  43.791
# Action_%:            -92.54
# Reward:              -12.164
#
#
# Episode:             17
# Age:                 19387
# Current_time_s:      77.3
# CalledAccel_in_ms2:  -16.58667
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  38.339
# Action_%:            -87.331
# Reward:              -10.65
#
#
# Episode:             17
# Age:                 19388
# Current_time_s:      77.4
# CalledAccel_in_ms2:  -15.32726
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  41.159
# Action_%:            -81.857
# Reward:              -11.433
#
#
# Episode:             17
# Age:                 19389
# Current_time_s:      77.5
# CalledAccel_in_ms2:  -14.907
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  41.786
# Action_%:            -80.002
# Reward:              -11.607
#
#
# Episode:             17
# Age:                 19390
# Current_time_s:      77.6
# CalledAccel_in_ms2:  -14.18778
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  36.613
# Action_%:            -76.791
# Reward:              -10.17
#
#
# Episode:             17
# Age:                 19391
# Current_time_s:      77.7
# CalledAccel_in_ms2:  -14.32576
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  44.123
# Action_%:            -77.41
# Reward:              -12.256
#
#
# Episode:             17
# Age:                 19392
# Current_time_s:      77.8
# CalledAccel_in_ms2:  -13.9729
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  34.525
# Action_%:            -75.822
# Reward:              -9.59
#
#
# Episode:             17
# Age:                 19393
# Current_time_s:      77.9
# CalledAccel_in_ms2:  -14.05599
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  43.313
# Action_%:            -76.197
# Reward:              -12.031
#
#
# Episode:             17
# Age:                 19394
# Current_time_s:      78.0
# CalledAccel_in_ms2:  -13.66087
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  42.872
# Action_%:            -74.409
# Reward:              -11.909
#
#
# Episode:             17
# Age:                 19395
# Current_time_s:      78.1
# CalledAccel_in_ms2:  -13.62273
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  43.622
# Action_%:            -74.236
# Reward:              -12.117
#
#
# Episode:             17
# Age:                 19396
# Current_time_s:      78.2
# CalledAccel_in_ms2:  -14.94864
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  37.682
# Action_%:            -80.186
# Reward:              -10.467
#
#
# Episode:             17
# Age:                 19397
# Current_time_s:      78.3
# CalledAccel_in_ms2:  -14.98203
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  34.685
# Action_%:            -80.334
# Reward:              -9.635
#
#
# Episode:             17
# Age:                 19398
# Current_time_s:      78.4
# CalledAccel_in_ms2:  -14.69626
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  34.487
# Action_%:            -79.065
# Reward:              -9.58
#
#
# Episode:             17
# Age:                 19399
# Current_time_s:      78.5
# CalledAccel_in_ms2:  -14.13272
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  38.694
# Action_%:            -76.543
# Reward:              -10.748
#
#
# Episode:             17
# Age:                 19400
# Current_time_s:      78.6
# CalledAccel_in_ms2:  -13.52808
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  40.946
# Action_%:            -73.805
# Reward:              -11.374
#
#
# Episode:             17
# Age:                 19401
# Current_time_s:      78.7
# CalledAccel_in_ms2:  -13.05548
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  35.419
# Action_%:            -71.641
# Reward:              -9.838
#
#
# Episode:             17
# Age:                 19402
# Current_time_s:      78.8
# CalledAccel_in_ms2:  -13.54907
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  41.157
# Action_%:            -73.9
# Reward:              -11.433
#
#
# Episode:             17
# Age:                 19403
# Current_time_s:      78.9
# CalledAccel_in_ms2:  -13.89924
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  37.252
# Action_%:            -75.49
# Reward:              -10.348
#
#
# Episode:             17
# Age:                 19404
# Current_time_s:      79.0
# CalledAccel_in_ms2:  -13.68804
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  44.244
# Action_%:            -74.532
# Reward:              -12.29
#
#
# Episode:             17
# Age:                 19405
# Current_time_s:      79.1
# CalledAccel_in_ms2:  -14.33955
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  39.114
# Action_%:            -77.472
# Reward:              -10.865
#
#
# Episode:             17
# Age:                 19406
# Current_time_s:      79.2
# CalledAccel_in_ms2:  -14.21521
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  35.617
# Action_%:            -76.914
# Reward:              -9.894
#
#
# Episode:             17
# Age:                 19407
# Current_time_s:      79.3
# CalledAccel_in_ms2:  -13.52223
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  38.826
# Action_%:            -73.778
# Reward:              -10.785
#
#
# Episode:             17
# Age:                 19408
# Current_time_s:      79.4
# CalledAccel_in_ms2:  -13.714
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  37.64
# Action_%:            -74.65
# Reward:              -10.455
#
#
# Episode:             17
# Age:                 19409
# Current_time_s:      79.5
# CalledAccel_in_ms2:  -12.87717
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  44.222
# Action_%:            -70.819
# Reward:              -12.284
#
#
# Episode:             17
# Age:                 19410
# Current_time_s:      79.6
# CalledAccel_in_ms2:  -13.31056
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  35.578
# Action_%:            -72.812
# Reward:              -9.883
#
#
# Episode:             17
# Age:                 19411
# Current_time_s:      79.7
# CalledAccel_in_ms2:  -12.8526
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  41.045
# Action_%:            -70.706
# Reward:              -11.401
#
#
# Episode:             17
# Age:                 19412
# Current_time_s:      79.8
# CalledAccel_in_ms2:  -12.89356
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  40.609
# Action_%:            -70.895
# Reward:              -11.28
#
#
# Episode:             17
# Age:                 19413
# Current_time_s:      79.9
# CalledAccel_in_ms2:  -13.1469
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  37.275
# Action_%:            -72.061
# Reward:              -10.354
#
#
# Episode:             17
# Age:                 19414
# Current_time_s:      80.0
# CalledAccel_in_ms2:  -13.43331
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  42.077
# Action_%:            -73.373
# Reward:              -11.688
#
#
# Episode:             17
# Age:                 19415
# Current_time_s:      80.1
# CalledAccel_in_ms2:  -13.81572
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  35.904
# Action_%:            -75.112
# Reward:              -9.973
#
#
# Episode:             17
# Age:                 19416
# Current_time_s:      80.2
# CalledAccel_in_ms2:  -14.19337
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  40.456
# Action_%:            -76.816
# Reward:              -11.238
#
#
# Episode:             17
# Age:                 19417
# Current_time_s:      80.3
# CalledAccel_in_ms2:  -14.50509
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  40.696
# Action_%:            -78.213
# Reward:              -11.304
#
#
# Episode:             17
# Age:                 19418
# Current_time_s:      80.4
# CalledAccel_in_ms2:  -13.88083
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  42.551
# Action_%:            -75.406
# Reward:              -11.82
#
#
# Episode:             17
# Age:                 19419
# Current_time_s:      80.5
# CalledAccel_in_ms2:  -13.04872
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  34.369
# Action_%:            -71.61
# Reward:              -9.547
#
#
# Episode:             17
# Age:                 19420
# Current_time_s:      80.6
# CalledAccel_in_ms2:  -12.44008
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  41.575
# Action_%:            -68.792
# Reward:              -11.549
#
#
# Episode:             17
# Age:                 19421
# Current_time_s:      80.7
# CalledAccel_in_ms2:  -14.1033
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  40.432
# Action_%:            -76.41
# Reward:              -11.231
#
#
# Episode:             17
# Age:                 19422
# Current_time_s:      80.8
# CalledAccel_in_ms2:  -14.63228
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  40.322
# Action_%:            -78.78
# Reward:              -11.201
#
#
# Episode:             17
# Age:                 19423
# Current_time_s:      80.9
# CalledAccel_in_ms2:  -14.93194
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  43.727
# Action_%:            -80.112
# Reward:              -12.146
#
#
# Episode:             17
# Age:                 19424
# Current_time_s:      81.0
# CalledAccel_in_ms2:  -14.70777
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  40.787
# Action_%:            -79.117
# Reward:              -11.33
#
#
# Episode:             17
# Age:                 19425
# Current_time_s:      81.1
# CalledAccel_in_ms2:  -14.27523
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  39.858
# Action_%:            -77.183
# Reward:              -11.072
#
#
# Episode:             17
# Age:                 19426
# Current_time_s:      81.2
# CalledAccel_in_ms2:  -13.39717
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  35.668
# Action_%:            -73.208
# Reward:              -9.908
#
#
# Episode:             17
# Age:                 19427
# Current_time_s:      81.3
# CalledAccel_in_ms2:  -14.28615
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  36.976
# Action_%:            -77.232
# Reward:              -10.271
#
#
# Episode:             17
# Age:                 19428
# Current_time_s:      81.4
# CalledAccel_in_ms2:  -13.25336
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  38.538
# Action_%:            -72.55
# Reward:              -10.705
#
#
# Episode:             17
# Age:                 19429
# Current_time_s:      81.5
# CalledAccel_in_ms2:  -13.18799
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  40.847
# Action_%:            -72.25
# Reward:              -11.346
#
#
# Episode:             17
# Age:                 19430
# Current_time_s:      81.6
# CalledAccel_in_ms2:  -13.89725
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  35.492
# Action_%:            -75.481
# Reward:              -9.859
#
#
# Episode:             17
# Age:                 19431
# Current_time_s:      81.7
# CalledAccel_in_ms2:  -14.52631
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  39.886
# Action_%:            -78.308
# Reward:              -11.079
#
#
# Episode:             17
# Age:                 19432
# Current_time_s:      81.8
# CalledAccel_in_ms2:  -14.22809
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  42.384
# Action_%:            -76.972
# Reward:              -11.773
#
#
# Episode:             17
# Age:                 19433
# Current_time_s:      81.9
# CalledAccel_in_ms2:  -13.52026
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  36.48
# Action_%:            -73.769
# Reward:              -10.133
#
#
# Episode:             17
# Age:                 19434
# Current_time_s:      82.0
# CalledAccel_in_ms2:  -13.68664
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  37.722
# Action_%:            -74.526
# Reward:              -10.478
#
#
# Episode:             17
# Age:                 19435
# Current_time_s:      82.1
# CalledAccel_in_ms2:  -14.23419
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  37.341
# Action_%:            -76.999
# Reward:              -10.372
#
#
# Episode:             17
# Age:                 19436
# Current_time_s:      82.2
# CalledAccel_in_ms2:  -14.65313
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  44.538
# Action_%:            -78.873
# Reward:              -12.372
#
#
# Episode:             17
# Age:                 19437
# Current_time_s:      82.3
# CalledAccel_in_ms2:  -16.39767
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  38.023
# Action_%:            -86.518
# Reward:              -10.562
#
#
# Episode:             17
# Age:                 19438
# Current_time_s:      82.4
# CalledAccel_in_ms2:  -16.59668
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  40.864
# Action_%:            -87.374
# Reward:              -11.351
#
#
# Episode:             17
# Age:                 19439
# Current_time_s:      82.5
# CalledAccel_in_ms2:  -15.40635
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  42.14
# Action_%:            -82.205
# Reward:              -11.706
#
#
# Episode:             17
# Age:                 19440
# Current_time_s:      82.6
# CalledAccel_in_ms2:  -15.58769
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  41.116
# Action_%:            -83.0
# Reward:              -11.421
#
#
# Episode:             17
# Age:                 19441
# Current_time_s:      82.7
# CalledAccel_in_ms2:  -15.58109
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  38.94
# Action_%:            -82.971
# Reward:              -10.817
#
#
# Episode:             17
# Age:                 19442
# Current_time_s:      82.8
# CalledAccel_in_ms2:  -16.92883
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  42.65
# Action_%:            -88.797
# Reward:              -11.847
#
#
# Episode:             17
# Age:                 19443
# Current_time_s:      82.9
# CalledAccel_in_ms2:  -17.23431
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:  35.555
# Action_%:            -90.098
# Reward:              -9.876
#
#
# Episode:             17
# Age:                 19444
# Current_time_s:      83.0
# CalledAccel_in_ms2:  -16.59615
# CurrentSpeed_in_kph: 0.0
# TargetSpeed_in_kph:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-46-fe06a91580c9> in <cell line: 14>()
#      46
#      47         # Recieve state and reward from environment.
# ---> 48         state, reward, done = env.step(action[0])
#      49
#      50         buffer.record((prev_state, action, reward, state))
#
# <ipython-input-38-1cc978c0d624> in step(self, ThrottleBrake_action)
#      51         print('CalledAccel_in_ms2: ', round(acceleration, 5))
#      52         print('CurrentSpeed_in_kph:', round(self.longitudinalVelocity*3.6, 3))
# ---> 53         print('TargetSpeed_in_kph: ', round(self.target_speed_follow*3.6, 3))
#      54         print('Action_%:           ', round(action*100,  3))
#      55         print('Reward:             ', round(reward_step, 3))
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/iostream.py in write(self, string)
#     400             is_child = (not self._is_master_process())
#     401             # only touch the buffer in the IO thread to avoid races
# --> 402             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     403             if is_child:
#     404                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/iostream.py in schedule(self, f)
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#     205             f()
#
# /usr/local/lib/python3.10/dist-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     616                 )
#     617             data.group = group
# --> 618         return super().send(data, flags=flags, copy=copy, track=track)
#     619
#     620     def send_multipart(
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# /usr/local/lib/python3.10/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
# Save the weights
actor_model.save_weights("pendulum_actor.h5")
critic_model.save_weights("pendulum_critic.h5")

target_actor.save_weights("pendulum_target_actor.h5")
target_critic.save_weights("pendulum_target_critic.h5")
